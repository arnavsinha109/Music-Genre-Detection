# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %% [markdown]
# The main aim of this notebook is to train models for 250 dataset using RNN GRU. We will use split network where it as two outputs and then merge.

# %%
musicFeatures = pd.read_pickle("./musicFeatures.pkl")

# %%
musicFeatures.shape
# Out:
# (26900, 22)

# %%
musicFeatures.head(3)
# Out:
#          id genre                                      mfccFeature_0  \
# 0  124425_0  Folk  [-367.4169, -240.58614, -193.78488, -180.29262...
# 1  124425_1  Folk  [-176.67264, -169.07156, -142.83098, -116.0994...
# 2  124425_2  Folk  [-112.90256, -84.587326, -92.53052, -99.84867,...
#
#                                        mfccFeature_1  \
# 0  [163.79123, 170.1294, 171.51189, 161.30435, 14...
# 1  [125.95861, 142.0693, 138.62712, 128.68915, 12...
# 2  [118.598724, 102.67175, 82.80994, 73.35031, 71...
#
#                                        mfccFeature_2  \
# 0  [6.0959854, -5.9718704, -3.6486344, -1.2554941...
# 1  [-42.819057, -54.282654, -64.97652, -73.68849,...
# 2  [-33.237568, -38.343197, -34.45424, -24.077305...
#
#                                        mfccFeature_3  \
# 0  [53.194122, 63.06723, 60.13885, 54.763412, 52....
# 1  [68.79902, 82.17572, 71.34984, 73.27362, 84.63...
# 2  [50.234768, 52.99376, 56.314552, 51.52988, 53....
#
#                                        mfccFeature_4  \
# 0  [16.68528, 19.538809, 19.626118, 18.60508, 23....
# 1  [15.051884, 15.13154, 15.273981, 14.384039, 15...
# 2  [18.136402, 22.863585, 18.818027, 11.438265, 8...
#
#                                        mfccFeature_5  \
# 0  [-23.51472, -19.84507, -16.962742, -13.548637,...
# 1  [-5.963161, -10.348415, -12.421081, -9.166971,...
# 2  [-23.589928, -19.38637, -15.253525, -5.8537474...
#
#                                        mfccFeature_6  \
# 0  [6.3363132, -1.276854, -5.610017, -4.050003, -...
# 1  [18.740742, 19.350863, 8.707056, 3.6187146, 1....
# 2  [11.365215, 6.558339, -1.7250502, -4.8964157, ...
#
#                                        mfccFeature_7  ...  \
# 0  [-20.14743, -24.12778, -16.919537, -7.6289234,...  ...
# 1  [-11.269847, -7.254199, 1.2921772, -1.4600475,...  ...
# 2  [-8.613762, -10.419959, -4.151663, -1.5471857,...  ...
#
#                                       mfccFeature_10  \
# 0  [3.951639, -4.166794, -8.241913, -9.794014, -1...
# 1  [-5.3846745, -10.779312, -19.985872, -18.81395...
# 2  [-19.939487, -16.535833, -21.92295, -25.605438...
#
#                                       mfccFeature_11  \
# 0  [5.920375, 9.249519, 8.353765, 11.909894, 14.4...
# 1  [12.694374, 11.362453, 8.072839, 4.8536325, -0...
# 2  [12.999569, 8.9071, 3.3847241, 5.747637, 2.470...
#
#                                       mfccFeature_12  \
# 0  [-12.381685, -16.062777, -16.373697, -15.77498...
# 1  [3.3793998, -0.6741159, -0.14108896, -5.083455...
# 2  [-5.4092526, -7.6361217, -13.698164, -13.45112...
#
#                                       mfccFeature_13  \
# 0  [-3.8526406, -3.5650363, -4.6753526, -5.407305...
# 1  [-19.578459, -20.371014, -11.236882, -7.421087...
# 2  [-0.42731082, -2.8598223, -1.4495995, 1.697975...
#
#                                       mfccFeature_14  \
# 0  [-4.4005404, -11.534243, -12.7789135, -14.0914...
# 1  [-8.606797, -10.857103, -13.955954, -13.888264...
# 2  [-14.1753845, -20.045826, -20.387835, -21.9254...
#
#                                       themeFeature_0  \
# 0  [-2.81877732, 0.0170741491, -2.23746324, -1.79...
# 1  [-2.81877732, 0.0170741491, -2.23746324, -1.79...
# 2  [-2.81877732, 0.0170741491, -2.23746324, -1.79...
#
#                                       themeFeature_1  \
# 0  [-0.648167074, -0.260594785, -1.02404821, 2.81...
# 1  [-0.648167074, -0.260594785, -1.02404821, 2.81...
# 2  [-0.648167074, -0.260594785, -1.02404821, 2.81...
#
#                                       themeFeature_2  \
# 0  [-0.6686466, 2.7766242, -1.6993774, -3.4631765...
# 1  [-0.6686466, 2.7766242, -1.6993774, -3.4631765...
# 2  [-0.6686466, 2.7766242, -1.6993774, -3.4631765...
#
#                                       themeFeature_3  \
# 0  [-0.7302982, 1.5127099, 1.2979797, 0.65926456,...
# 1  [-0.7302982, 1.5127099, 1.2979797, 0.65926456,...
# 2  [-0.7302982, 1.5127099, 1.2979797, 0.65926456,...
#
#                                       themeFeature_4
# 0  [-2.26469612, 3.18752861, -1.83492291, 1.09744...
# 1  [-2.26469612, 3.18752861, -1.83492291, 1.09744...
# 2  [-2.26469612, 3.18752861, -1.83492291, 1.09744...
#
# [3 rows x 22 columns]

# %%
"""
Verifying all shapres and types of data
"""
print(musicFeatures.shape)
print('MFCC Features \n')
print(type(musicFeatures['mfccFeature_0'].iloc[0]))
print(len(musicFeatures['mfccFeature_0'].iloc[0]))
print(type(musicFeatures['mfccFeature_0'].iloc[0][0]))

print('Theme Features \n')
print(type(musicFeatures['themeFeature_0'].iloc[0]))
print(musicFeatures['themeFeature_0'].iloc[0].size)
print(type(musicFeatures['themeFeature_0'].iloc[0][0]))
# Out:
# (26900, 22)
# MFCC Features
#
# <class 'numpy.ndarray'>
# 250
# <class 'numpy.float64'>
# Theme Features
#
# <class 'numpy.ndarray'>
# 250
# <class 'numpy.float64'>

# %% [markdown]
# We split the dataset into x and y, y having the predicting columns

# %%
#Spliting x and y

y = musicFeatures['genre']
x = musicFeatures.loc[:, musicFeatures.columns != 'genre']
x = x.drop(['id'],axis =1)

print(x.shape)
print(y.shape)
# Out:
# (26900, 20)
# (26900,)

# %% [markdown]
# Since we have an np array as in each cell, we need to reshape the data into a 3rd array for the network, we use the following function for the same.

# %%
def convertTo3DnpArray(df):
    new = []

    for index, row in df.iterrows():
        temp = []
        for i in row:
            temp.append(i)
        temp = np.stack(temp, axis=1)
        new.append(temp)
    new = np.stack(new, axis=0)
    
    return new

# %% [markdown]
# We split the dataset into train,test and valid which is of the ratio 80:10:10. Each model is trained on train and tested on test, once the best model is identified, we do a final validation on valid dataset.

# %%
#Train test valid split

x_train_temp, x_valid, y_train_temp, y_valid = train_test_split(x,y,test_size=0.1,random_state=12,stratify=y)
x_train, x_test, y_train, y_test = train_test_split(x_train_temp,y_train_temp,test_size=0.1/0.9,random_state=12,stratify=y_train_temp)

print('Final Sizes of all datasets')
print('x_train :',x_train.shape)
print('x_test :',x_test.shape)
print('x_valid :',x_valid.shape)
print('y_train :',y_train.shape)
print('y_test :',y_test.shape)
print('y_valid :',y_valid.shape)
print(' \n')

print('Value counts ')
print('y_train :')
print(y_train.value_counts())
print('y_test :')
print(y_test.value_counts())
print('y_valid :')
print(y_valid.value_counts())
# Out:
# Final Sizes of all datasets
# x_train : (21520, 20)
# x_test : (2690, 20)
# x_valid : (2690, 20)
# y_train : (21520,)
# y_test : (2690,)
# y_valid : (2690,)
#
#
# Value counts
# y_train :
# Rock            3820
# Hip-Hop         3304
# Experimental    3228
# Folk            3224
# Electronic      3192
# Pop             2428
# Instrumental    2324
# Name: genre, dtype: int64
# y_test :
# Rock            477
# Hip-Hop         413
# Experimental    404
# Folk            403
# Electronic      399
# Pop             303
# Instrumental    291
# Name: genre, dtype: int64
# y_valid :
# Rock            478
# Hip-Hop         413
# Folk            403
# Experimental    403
# Electronic      399
# Pop             304
# Instrumental    290
# Name: genre, dtype: int64

# %% [markdown]
# Although the audio and theme features are numbers, they represent two different types of data. So we need to split them since the network will take them as two seperate inputs.

# %%
#splitting dataset into two parts

x_train_audio = convertTo3DnpArray(x_train.iloc[:,0:15])
x_test_audio = convertTo3DnpArray(x_test.iloc[:,0:15])
x_valid_audio = convertTo3DnpArray(x_valid.iloc[:,0:15])

x_train_theme = convertTo3DnpArray(x_train.iloc[:,15:])
x_test_theme = convertTo3DnpArray(x_test.iloc[:,15:])
x_valid_theme = convertTo3DnpArray(x_valid.iloc[:,15:])

print(x_train_audio.shape,x_train_theme.shape)
# Out:
# (21520, 250, 15) (21520, 250, 5)

# %%
x_train.iloc[:,0:15]
# Out:
#                                            mfccFeature_0  \
# 35394  [-259.05927, -239.89516, -210.36134, -191.0854...
# 34049  [-188.014, -206.20021, -225.0521, -220.18987, ...
# 34247  [-82.13368, -56.982624, -58.14949, -60.955105,...
# 35132  [-74.62353, -47.188427, -43.740658, -31.355085...
# 22687  [-10.387641, -2.7015615, -25.830664, -42.18832...
# ...                                                  ...
# 34612  [-22.075876, 17.469933, 41.13768, 47.155334, 2...
# 16319  [-92.643814, -106.90123, -146.92157, -146.6631...
# 32007  [-46.454754, -11.053625, -34.104454, -86.73249...
# 25302  [-67.69743, -45.990658, -48.59186, -45.082943,...
# 14597  [-431.63876, -425.94974, -425.71237, -416.3972...
#
#                                            mfccFeature_1  \
# 35394  [95.85247, 89.139465, 100.31354, 114.44683, 12...
# 34049  [128.69154, 141.3887, 154.6398, 159.06891, 149...
# 34247  [74.79721, 72.48038, 69.69021, 71.89056, 76.14...
# 35132  [110.29732, 108.80856, 104.4259, 102.99172, 10...
# 22687  [105.466125, 105.41113, 110.17697, 114.190765,...
# ...                                                  ...
# 34612  [14.399874, 3.0151532, 16.520775, 45.73943, 68...
#
#                                           mfccFeature_14
# 35394  [8.006058, 4.326626, -4.908849, -5.9096045, -3...
# 34049  [-3.9182348, -0.5984701, -4.849672, -3.298818,...
# 34247  [-2.1842833, -4.0735054, -3.4050357, -2.386907...
# 35132  [-5.083339, -7.525996, -2.9894814, -2.4445453,...
# 22687  [-3.5034661, -6.879369, -16.585663, -13.973838...
# ...                                                  ...
# 34612  [-4.7504263, -5.1601734, -0.3604851, -3.151796...
# 16319  [-4.008854, -0.82648444, 2.7306085, 3.3793988,...
# 32007  [-11.326896, -5.3240585, -5.435748, -7.47067, ...
# 25302  [-3.411292, -13.45058, -22.81018, -18.640976, ...
# 14597  [-5.4712257, -3.5024533, -3.082234, -5.5866365...
#
# [21520 rows x 15 columns]

# %% [markdown]
# We convert the y values into one hot encoded values.

# %%
ohe = OneHotEncoder()

y_valid = ohe.fit_transform(y_valid.values.reshape(-1, 1)).toarray()
y_train = ohe.fit_transform(y_train.values.reshape(-1, 1)).toarray()
y_test  = ohe.fit_transform(y_test .values.reshape(-1, 1)).toarray()

print('Verifying size')
print('y_train :',y_train.shape)
print('y_test :',y_test.shape)
print('y_valid :',y_valid.shape)
# Out:
# Verifying size
# y_train : (21520, 7)
# y_test : (2690, 7)
# y_valid : (2690, 7)

# %%
from keras.models import Sequential,load_model
from keras.layers import Dense,GRU,Flatten,concatenate,Dropout,LSTM
import tensorflow as tf
from keras import Model
from keras.layers import Input, Dense, Bidirectional
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Test acc')
    plt.title('Training and test accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Test loss')
    plt.title('Training and test loss')
    plt.legend()

# %% [markdown]
# The first model has small layers of GRU on both sides

# %%
#Input layers
audio_in = Input(shape=(x_train_audio.shape[1], x_train_audio.shape[2]), name='audio_in')
theme_in = Input(shape=(x_train_theme.shape[1], x_train_theme.shape[2]), name='theme_in')



#Audio layer
audio_GRU1 = GRU(64,return_sequences=True)(audio_in)
audio_GRU2 = GRU(64)(audio_GRU1)
audio_dense = Dense(64, activation='relu')(audio_GRU2)


#Theme layer

theme_GRU1 = GRU(64,return_sequences=True)(theme_in)
theme_GRU2 = GRU(64)(theme_GRU1)
theme_dense = Dense(64, activation='relu')(theme_GRU2)


#Concatenation 
concat = concatenate([audio_dense, theme_dense])
dense1 = Dense(64, activation='relu')(concat)
dense2 = Dense(32, activation='relu')(dense1)
dense3 = Dense(16, activation='relu')(dense2)
op = Dense(7, activation='softmax',name='op')(dense3)


model = Model(inputs=[audio_in,theme_in], outputs=[op])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  audio_in (InputLayer)          [(None, 250, 15)]    0           []
#
#  theme_in (InputLayer)          [(None, 250, 5)]     0           []
#
#  gru_2 (GRU)                    (None, 250, 64)      15552       ['audio_in[0][0]']
#
#  gru_4 (GRU)                    (None, 250, 64)      13632       ['theme_in[0][0]']
#
#  gru_3 (GRU)                    (None, 64)           24960       ['gru_2[0][0]']
#
#  gru_5 (GRU)                    (None, 64)           24960       ['gru_4[0][0]']
#
#  dense (Dense)                  (None, 64)           4160        ['gru_3[0][0]']
#
#  dense_1 (Dense)                (None, 64)           4160        ['gru_5[0][0]']
#
#  concatenate (Concatenate)      (None, 128)          0           ['dense[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 64)           8256        ['concatenate[0][0]']
#
#  dense_3 (Dense)                (None, 32)           2080        ['dense_2[0][0]']
#
#  dense_4 (Dense)                (None, 16)           528         ['dense_3[0][0]']
#
#  op (Dense)                     (None, 7)            119         ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 98,407
# Trainable params: 98,407
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#Simple model

model.compile(optimizer = 'adam',
                     loss='categorical_crossentropy',
                     metrics = ['accuracy']
                     )


h=model.fit({'audio_in': x_train_audio, 'theme_in': x_train_theme},{'op': y_train},
              epochs=50, batch_size=32,
            validation_data=({'audio_in': x_test_audio, 'theme_in': x_test_theme},{'op': y_test}))


model.save('simple_rnn_GRU_model')


plot_history(h)
# Out:
# Epoch 1/50
# 673/673 [==============================] - 85s 121ms/step - loss: 1.5789 - accuracy: 0.3933 - val_loss: 1.4214 - val_accuracy: 0.4736
# Epoch 2/50
# 673/673 [==============================] - 80s 119ms/step - loss: 1.3459 - accuracy: 0.5080 - val_loss: 1.2961 - val_accuracy: 0.5331
# Epoch 3/50
# 673/673 [==============================] - 81s 120ms/step - loss: 1.2194 - accuracy: 0.5589 - val_loss: 1.2062 - val_accuracy: 0.5691
# Epoch 4/50
# 673/673 [==============================] - 81s 120ms/step - loss: 1.0886 - accuracy: 0.6122 - val_loss: 1.0882 - val_accuracy: 0.6112
# Epoch 5/50
# 673/673 [==============================] - 81s 121ms/step - loss: 0.9542 - accuracy: 0.6637 - val_loss: 0.9600 - val_accuracy: 0.6691
# Epoch 6/50
# 673/673 [==============================] - 81s 121ms/step - loss: 0.8150 - accuracy: 0.7140 - val_loss: 0.8827 - val_accuracy: 0.6881
# Epoch 7/50
# 673/673 [==============================] - 83s 123ms/step - loss: 0.6906 - accuracy: 0.7602 - val_loss: 0.8201 - val_accuracy: 0.7145
# Epoch 8/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.5943 - accuracy: 0.7925 - val_loss: 0.7300 - val_accuracy: 0.7498
# Epoch 9/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.5095 - accuracy: 0.8217 - val_loss: 0.6712 - val_accuracy: 0.7636
# Epoch 10/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.4506 - accuracy: 0.8456 - val_loss: 0.6297 - val_accuracy: 0.7833
# Epoch 11/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.3924 - accuracy: 0.8620 - val_loss: 0.5844 - val_accuracy: 0.8052
# Epoch 12/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.3549 - accuracy: 0.8767 - val_loss: 0.6110 - val_accuracy: 0.8004
# Epoch 13/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.3203 - accuracy: 0.8889 - val_loss: 0.6251 - val_accuracy: 0.7948
# Epoch 14/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.2924 - accuracy: 0.8982 - val_loss: 0.5460 - val_accuracy: 0.8245
# Epoch 15/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.2695 - accuracy: 0.9062 - val_loss: 0.5352 - val_accuracy: 0.8338
# Epoch 16/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.2508 - accuracy: 0.9115 - val_loss: 0.5614 - val_accuracy: 0.8234
# Epoch 17/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.2366 - accuracy: 0.9176 - val_loss: 0.5787 - val_accuracy: 0.8234
# Epoch 18/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.2237 - accuracy: 0.9212 - val_loss: 0.5926 - val_accuracy: 0.8164
# Epoch 19/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.2066 - accuracy: 0.9288 - val_loss: 0.5339 - val_accuracy: 0.8446
# Epoch 20/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.1957 - accuracy: 0.9322 - val_loss: 0.5697 - val_accuracy: 0.8331
# Epoch 21/50
# 673/673 [==============================] - 82s 121ms/step - loss: 0.1910 - accuracy: 0.9334 - val_loss: 0.5078 - val_accuracy: 0.8435
# Epoch 22/50
# 673/673 [==============================] - 83s 123ms/step - loss: 0
50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.0952 - accuracy: 0.9678 - val_loss: 0.6546 - val_accuracy: 0.8487
# Epoch 47/50
# 673/673 [==============================] - 84s 126ms/step - loss: 0.0970 - accuracy: 0.9673 - val_loss: 0.5904 - val_accuracy: 0.8565
# Epoch 48/50
# 673/673 [==============================] - 84s 125ms/step - loss: 0.0870 - accuracy: 0.9697 - val_loss: 0.5922 - val_accuracy: 0.8591
# Epoch 49/50
# 673/673 [==============================] - 83s 123ms/step - loss: 0.0866 - accuracy: 0.9703 - val_loss: 0.6143 - val_accuracy: 0.8517
# Epoch 50/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.1137 - accuracy: 0.9610 - val_loss: 0.5926 - val_accuracy: 0.8580
# WARNING:absl:Found untraced functions such as gru_cell_2_layer_call_fn, gru_cell_2_layer_call_and_return_conditional_losses, gru_cell_4_layer_call_fn, gru_cell_4_layer_call_and_return_conditional_losses, gru_cell_3_layer_call_fn while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: simple_rnn_GRU_model\assets
# INFO:tensorflow:Assets written to: simple_rnn_GRU_model\assets
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001C327576E80> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001C32E6B9850> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001C3595136D0> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001C32E6B40D0> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %% [markdown]
# We add some regularization over the previous architecture

# %%
#Input layers
audio_in = Input(shape=(x_train_audio.shape[1], x_train_audio.shape[2]), name='audio_in')
theme_in = Input(shape=(x_train_theme.shape[1], x_train_theme.shape[2]), name='theme_in')



#Audio layer
audio_GRU1 = GRU(64,return_sequences=True,dropout=0.2)(audio_in)
audio_GRU2 = GRU(64,dropout=0.1,recurrent_dropout=0.1)(audio_GRU1)
audio_dense = Dense(64, activation='relu')(audio_GRU2)


#Theme layer

theme_GRU1 = GRU(64,return_sequences=True,dropout=0.2)(theme_in)
theme_GRU2 = GRU(64,dropout=0.1,recurrent_dropout=0.1)(theme_GRU1)
theme_dense = Dense(64, activation='relu')(theme_GRU2)


#Concatenation 
concat = concatenate([audio_dense, theme_dense])
dense1 = Dense(64, activation='relu')(concat)
drop1 = Dropout(0.1)(dense1)
dense2 = Dense(32, activation='relu')(drop1)
dense3 = Dense(16, activation='relu')(dense2)
op = Dense(7, activation='softmax',name='op')(dense3)


model2 = Model(inputs=[audio_in,theme_in], outputs=[op])

model2.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  audio_in (InputLayer)          [(None, 250, 15)]    0           []
#
#  theme_in (InputLayer)          [(None, 250, 5)]     0           []
#
#  gru_6 (GRU)                    (None, 250, 64)      15552       ['audio_in[0][0]']
#
#  gru_8 (GRU)                    (None, 250, 64)      13632       ['theme_in[0][0]']
#
#  gru_7 (GRU)                    (None, 64)           24960       ['gru_6[0][0]']
#
#  gru_9 (GRU)                    (None, 64)           24960       ['gru_8[0][0]']
#
#  dense_5 (Dense)                (None, 64)           4160        ['gru_7[0][0]']
#
#  dense_6 (Dense)                (None, 64)           4160        ['gru_9[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 128)          0           ['dense_5[0][0]',
#                                                                   'dense_6[0][0]']
#
#  dense_7 (Dense)                (None, 64)           8256        ['concatenate_1[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['dense_7[0][0]']
#
#  dense_8 (Dense)                (None, 32)           2080        ['dropout[0][0]']
#
#  dense_9 (Dense)                (None, 16)           528         ['dense_8[0][0]']
#
#  op (Dense)                     (None, 7)            119         ['dense_9[0][0]']
#
# ==================================================================================================
# Total params: 98,407
# Trainable params: 98,407
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#Adding a dropout

model2.compile(optimizer = 'adam',
                     loss='categorical_crossentropy',
                     metrics = ['accuracy']
                     )


h=model2.fit({'audio_in': x_train_audio, 'theme_in': x_train_theme},{'op': y_train},
              epochs=50, batch_size=32,
            validation_data=({'audio_in': x_test_audio, 'theme_in': x_test_theme},{'op': y_test}))


model2.save('simple_rnn_GRU_model_dropout')


plot_history(h)
# Out:
# Epoch 1/50
# 673/673 [==============================] - 94s 134ms/step - loss: 1.6483 - accuracy: 0.3627 - val_loss: 1.6238 - val_accuracy: 0.3907
# Epoch 45/50
# 673/673 [==============================] - 89s 132ms/step - loss: 0.6565 - accuracy: 0.7625 - val_loss: 0.9269 - val_accuracy: 0.6974
# Epoch 46/50
# 673/673 [==============================] - 105s 156ms/step - loss: 0.6433 - accuracy: 0.7711 - val_loss: 0.9416 - val_accuracy: 0.6996
# Epoch 47/50
# 673/673 [==============================] - 100s 148ms/step - loss: 0.6432 - accuracy: 0.7700 - val_loss: 0.9266 - val_accuracy: 0.6941
# Epoch 48/50
# 673/673 [==============================] - 99s 147ms/step - loss: 0.6399 - accuracy: 0.7697 - val_loss: 0.8890 - val_accuracy: 0.7197
# Epoch 49/50
# 673/673 [==============================] - 92s 137ms/step - loss: 0.6242 - accuracy: 0.7789 - val_loss: 0.8739 - val_accuracy: 0.7257
# Epoch 50/50
# 673/673 [==============================] - 84s 126ms/step - loss: 0.6298 - accuracy: 0.7758 - val_loss: 0.8368 - val_accuracy: 0.7279
# WARNING:absl:Found untraced functions such as gru_cell_2_layer_call_fn, gru_cell_2_layer_call_and_return_conditional_losses, gru_cell_4_layer_call_fn, gru_cell_4_layer_call_and_return_conditional_losses, gru_cell_3_layer_call_fn while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: simple_rnn_GRU_model_dropout\assets
# INFO:tensorflow:Assets written to: simple_rnn_GRU_model_dropout\assets
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001C327576E80> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001C32E6B9850> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001C3595136D0> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001C32E6B40D0> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
h2=model2.fit({'audio_in': x_train_audio, 'theme_in': x_train_theme},{'op': y_train},
              epochs=50, batch_size=32,
            validation_data=({'audio_in': x_test_audio, 'theme_in': x_test_theme},{'op': y_test}))


model2.save('simple_rnn_GRU_model_dropout_cont')


plot_history(h2)
# Out:
# Epoch 1/50
# 673/673 [==============================] - 92s 136ms/step - loss: 0.6291 - accuracy: 0.7772 - val_loss: 0.9236 - val_accuracy: 0.7059
# Epoch 2/50
# 673/673 [==============================] - 85s 126ms/step - loss: 0.6173 - accuracy: 0.7796 - val_loss: 0.9504 - val_accuracy: 0.7082
# Epoch 3/50
# 673/673 [==============================] - 83s 124ms/step - loss: 0.6056 - accuracy: 0.7848 - val_loss: 0.9429 - val_accuracy: 0.7048
# Epoch 4/50
# 673/673 [==============================] - 84s 124ms/step - loss: 0.6048 - accuracy: 0.7879 - val_loss: 0.8981 - val_accuracy: 0.7160
# Epoch 5/50
# 673/673 [==============================] - 83s 123ms/step - loss: 0.5960 - accuracy: 0.7901 - val_loss: 0.7940 - val_accuracy: 0.7375
# Epoch 6/50
# 673/673 [==============================] - 83s 123ms/step - loss: 0.6029 - accuracy: 0.7874 - val_loss: 0.8876 - val_accuracy: 0.7227
# Epoch 7/50
# 673/673 [==============================] - 86s 128ms/step - loss: 0.5912 - accuracy: 0.7908 - val_loss: 0.8212 - val_accuracy: 0.7327
# Epoch 8/50
# 673/673 [==============================] - 93s 138ms/step - loss: 0.5935 - accuracy: 0.7891 - val_loss: 0.9164 - val_accuracy: 0.7126
# Epoch 9/50
# 673/673 [==============================] - 93s 138ms/step - loss: 0.5859 - accuracy: 0.7913 - val_loss: 0.8299 - val_accuracy: 0.7271
# Epoch 10/50
# 673/673 [==============================] - 92s 136ms/step - loss: 0.5780 - accuracy: 0.7919 - val_loss: 0.7767 - val_accuracy: 0.7550
# Epoch 11/50
# 673/673 [==============================] - 83s 123ms/step - loss: 0.5778 - accuracy: 0.7929 - val_loss: 0.7892 - val_accuracy: 0.7435
# Epoch 12/50
# 673/673 [==============================] - 83s 123ms/step - loss: 0.5678 - accuracy: 0.8008 - val_loss: 0.8109 - val_accuracy: 0.7461
# Epoch 13/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.
50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.4751 - accuracy: 0.8320 - val_loss: 0.8155 - val_accuracy: 0.7498
# Epoch 42/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.4734 - accuracy: 0.8324 - val_loss: 0.7914 - val_accuracy: 0.7621
# Epoch 43/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.4712 - accuracy: 0.8313 - val_loss: 0.7880 - val_accuracy: 0.7654
# Epoch 44/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.4665 - accuracy: 0.8362 - val_loss: 0.7634 - val_accuracy: 0.7688
# Epoch 45/50
# 673/673 [==============================] - 83s 124ms/step - loss: 0.4691 - accuracy: 0.8342 - val_loss: 0.8158 - val_accuracy: 0.7695
# Epoch 46/50
# 673/673 [==============================] - 83s 123ms/step - loss: 0.4637 - accuracy: 0.8378 - val_loss: 0.7806 - val_accuracy: 0.7658
# Epoch 47/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.4672 - accuracy: 0.8351 - val_loss: 0.8542 - val_accuracy: 0.7383
# Epoch 48/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.4496 - accuracy: 0.8414 - val_loss: 0.7725 - val_accuracy: 0.7610
# Epoch 49/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.4537 - accuracy: 0.8416 - val_loss: 0.8015 - val_accuracy: 0.7647
# Epoch 50/50
# 673/673 [==============================] - 82s 122ms/step - loss: 0.4663 - accuracy: 0.8373 - val_loss: 0.7988 - val_accuracy: 0.7587
# WARNING:absl:Found untraced functions such as gru_cell_6_layer_call_fn, gru_cell_6_layer_call_and_return_conditional_losses, gru_cell_8_layer_call_fn, gru_cell_8_layer_call_and_return_conditional_losses, gru_cell_7_layer_call_fn while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: simple_rnn_GRU_model_dropout_cont\assets
# INFO:tensorflow:Assets written to: simple_rnn_GRU_model_dropout_cont\assets
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001C3E9458E80> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001C3CD69A310> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001C3CC29AF10> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001C3CD9F1850> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
#Model performance similar to LSTM

h2=model2.fit({'audio_in': x_train_audio, 'theme_in': x_train_theme},{'op': y_train},
              epochs=50, batch_size=32,
            validation_data=({'audio_in': x_test_audio, 'theme_in': x_test_theme},{'op': y_test}))


model2.save('simple_rnn_GRU_model_dropout_cont_2')


plot_history(h2)
# Out:
# Epoch 1/50
# 673/673 [==============================] - 104s 154ms/step - loss: 0.4496 - accuracy: 0.8403 - val_loss: 0.7225 - val_accuracy: 0.7651
# Epoch 2/50
# 673/673 [==============================] - 98s 146ms/step - loss: 0.4567 - accuracy: 0.8385 - val_loss: 0.7409 - val_accuracy: 0.7766
# Epoch 3/50
# 673/673 [==============================] - 98s 146ms/step - loss: 0.4549 - accuracy: 0.8401 - val_loss: 0.8009 - val_accuracy: 0.7665
# Epoch 4/50
# 673/673 [==============================] - 98s 146ms/step - loss: 0.4559 - accuracy: 0.8403 - val_loss: 0.8093 - val_accuracy: 0.7517
# Epoch 5/50
# 673/673 [==============================] - 98s 146ms/step - loss: 0.4489 - accuracy: 0.8379 - val_loss: 0.7655 - val_accuracy: 0.7766
# Epoch 6/50
# 673/673 [==============================] - 99s 147ms/step - loss: 0.4417 - accuracy: 0.8446 - val_loss: 0.8183 - val_accuracy: 0.7595
# Epoch 7/50
# 673/673 [==============================] - 98s 146ms/step - loss: 0.4409 - accuracy: 0.8450 - val_loss: 0.7706 - val_accuracy: 0.7684
# Epoch 8/50
# 673/673 [==============================] - 99s 147ms/step - loss: 0.4339 - accuracy: 0.8499 - val_loss: 0.7090 - val_accuracy: 0.7885
# Epoch 9/50
# 673/673 [==============================] - 98s 146ms/step - loss: 0.4278 - accuracy: 0.8496 - val_loss: 0.8364 - val_accuracy: 0.7632
# Epoch 10/50
# 673/673 [==============================] - 98s 146ms/step - loss: 0.4363 - accuracy: 0.8480 - val_loss: 0.7448 - val_accuracy: 0.7669
# Epoch 11/50
# 673/673 [==============================] - 99s 146ms/step - loss: 0.4381 - accuracy: 0.8455 - val_loss: 0.8424 - val_accuracy: 0.7561
# Epoch 12/50
# 673/673 [==============================] - 98s 146ms/step - loss: 0.4302 - accuracy: 0.8494 - val_loss: 0.8018 - val_accuracy: 0.7617
# Epoch 13/50
# 673/673 [==============================] - 99s 147ms/step - loss: 0.4347 - accuracy: 0.8478 - val_loss: 0.7023 - val_accuracy: 0.7755
# Epoch 14/50
# 673/673 [==============================] - 98s 146ms/step - loss: 0.
# Epoch 36/50
# 673/673 [==============================] - 113s 168ms/step - loss: 0.3985 - accuracy: 0.8606 - val_loss: 0.7668 - val_accuracy: 0.7810
# Epoch 37/50
# 673/673 [==============================] - 105s 155ms/step - loss: 0.3910 - accuracy: 0.8637 - val_loss: 0.7933 - val_accuracy: 0.7740
# Epoch 38/50
# 673/673 [==============================] - 108s 160ms/step - loss: 0.3911 - accuracy: 0.8628 - val_loss: 0.7455 - val_accuracy: 0.7755
# Epoch 39/50
# 673/673 [==============================] - 106s 157ms/step - loss: 0.3878 - accuracy: 0.8635 - val_loss: 0.7650 - val_accuracy: 0.7721
# Epoch 40/50
# 673/673 [==============================] - 111s 165ms/step - loss: 0.3859 - accuracy: 0.8657 - val_loss: 0.8337 - val_accuracy: 0.7617
# Epoch 41/50
# 673/673 [==============================] - 101s 150ms/step - loss: 0.3799 - accuracy: 0.8649 - val_loss: 0.7255 - val_accuracy: 0.7792
# Epoch 42/50
# 673/673 [==============================] - 114s 169ms/step - loss: 0.3815 - accuracy: 0.8652 - val_loss: 0.8022 - val_accuracy: 0.7695
# Epoch 43/50
# 673/673 [==============================] - 113s 168ms/step - loss: 0.3886 - accuracy: 0.8641 - val_loss: 0.7961 - val_accuracy: 0.7825
# Epoch 44/50
# 673/673 [==============================] - 121s 179ms/step - loss: 0.3669 - accuracy: 0.8716 - val_loss: 0.9249 - val_accuracy: 0.7454
# Epoch 45/50
# 673/673 [==============================] - 115s 170ms/step - loss: 0.3795 - accuracy: 0.8672 - val_loss: 0.7814 - val_accuracy: 0.7732
# Epoch 46/50
# 673/673 [==============================] - 107s 159ms/step - loss: 0.3695 - accuracy: 0.8688 - val_loss: 0.8922 - val_accuracy: 0.7535
# Epoch 47/50
# 673/673 [==============================] - 106s 157ms/step - loss: 0.3837 - accuracy: 0.8651 - val_loss: 0.7518 - val_accuracy: 0.7840
# Epoch 48/50
# 673/673 [==============================] - 107s 159ms/step - loss: 0.3782 - accuracy: 0.8680 - val_loss: 0.7160 - val_accuracy: 0.7833
# Epoch 49/50
# 673/673 [==============================] - 109s 163ms/step - loss: 0.3735 - accuracy: 0.8690 - val_loss: 0.7613 - val_accuracy: 0.7651
# Epoch 50/50
# 673/673 [==============================] - 104s 154ms/step - loss: 0.3707 - accuracy: 0.8709 - val_loss: 0.7234 - val_accuracy: 0.7911
# WARNING:absl:Found untraced functions such as gru_cell_6_layer_call_fn, gru_cell_6_layer_call_and_return_conditional_losses, gru_cell_8_layer_call_fn, gru_cell_8_layer_call_and_return_conditional_losses, gru_cell_7_layer_call_fn while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: simple_rnn_GRU_model_dropout_cont_2\assets
# INFO:tensorflow:Assets written to: simple_rnn_GRU_model_dropout_cont_2\assets
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001C3E9458E80> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001C3CD69A310> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001C3CC29AF10> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001C3CD9F1850> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %% [markdown]
# We remove all regularizers and then use a mix of both GRU and LSTM

# %%
#Input layers
audio_in = Input(shape=(x_train_audio.shape[1], x_train_audio.shape[2]), name='audio_in')
theme_in = Input(shape=(x_train_theme.shape[1], x_train_theme.shape[2]), name='theme_in')



#Audio layer
audio_LSTM1 = LSTM(64,return_sequences=True)(audio_in)
audio_LSTM2 = LSTM(64)(audio_LSTM1)
audio_dense = Dense(64, activation='relu')(audio_LSTM2)


#Theme layer

theme_GRU1 = GRU(64,return_sequences=True)(theme_in)
theme_GRU2 = GRU(64)(theme_GRU1)
theme_dense = Dense(64, activation='relu')(theme_GRU2)


#Concatenation 
concat = concatenate([audio_dense, theme_dense])
dense1 = Dense(64, activation='relu')(concat)
dense2 = Dense(32, activation='relu')(dense1)
dense3 = Dense(16, activation='relu')(dense2)
op = Dense(7, activation='softmax',name='op')(dense3)


model3 = Model(inputs=[audio_in,theme_in], outputs=[op])

model3.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  audio_in (InputLayer)          [(None, 250, 15)]    0           []
#
#  theme_in (InputLayer)          [(None, 250, 5)]     0           []
#
#  lstm_2 (LSTM)                  (None, 250, 64)      20480       ['audio_in[0][0]']
#
#  gru_16 (GRU)                   (None, 250, 64)      13632       ['theme_in[0][0]']
#
#  lstm_3 (LSTM)                  (None, 64)           33024       ['lstm_2[0][0]']
#
#  gru_17 (GRU)                   (None, 64)           24960       ['gru_16[0][0]']
#
#  dense_20 (Dense)               (None, 64)           4160        ['lstm_3[0][0]']
#
#  dense_21 (Dense)               (None, 64)           4160        ['gru_17[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 128)          0           ['dense_20[0][0]',
#                                                                   'dense_21[0][0]']
#
#  dense_22 (Dense)               (None, 64)           8256        ['concatenate_4[0][0]']
#
#  dense_23 (Dense)               (None, 32)           2080        ['dense_22[0][0]']
#
#  dense_24 (Dense)               (None, 16)           528         ['dense_23[0][0]']
#
#  op (Dense)                     (None, 7)            119         ['dense_24[0][0]']
#
# ==================================================================================================
# Total params: 111,399
# Trainable params: 111,399
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model3.compile(optimizer = 'adam',
                     loss='categorical_crossentropy',
                     metrics = ['accuracy']
                     )


h3=model3.fit({'audio_in': x_train_audio, 'theme_in': x_train_theme},{'op': y_train},
              epochs=50, batch_size=32,
            validation_data=({'audio_in': x_test_audio, 'theme_in': x_test_theme},{'op': y_test}))


model3.save('mixed_rnn_model')


plot_history(h3)
# Out:
# Epoch 1/50
# 673/673 [==============================] - 125s 179ms/step - loss: 1.6227 - accuracy: 0.3765 - val_loss: 1.4940 - val_accuracy: 0.4532
# Epoch 2/50
# 673/673 [==============================] - 104s 155ms/step - loss: 1.4330 - accuracy: 0.4701 - val_loss: 1.4095 - val_accuracy: 0.4963
# Epoch 3/50
# 673/673 [==============================] - 98s 145ms/step - loss: 1.3365 - accuracy: 0.5134 - val_loss: 1.3490 - val_accuracy: 0.5104
# Epoch 4/50
# 673/673 [==============================] - 98s 145ms/step - loss: 1.2271 - accuracy: 0.5555 - val_loss: 1.2051 - val_accuracy: 0.5587
# Epoch 5/50
# 673/673 [==============================] - 98s 145ms/step - loss: 1.0893 - accuracy: 0.6121 - val_loss: 1.0988 - val_accuracy: 0.6063
# Epoch 6/50
# 673/673 [==============================] - 98s 145ms/step - loss: 0.9705 - accuracy: 0.6581 - val_loss: 0.9876 - val_accuracy: 0.6461
# Epoch 7/50
# 673/673 [==============================] - 103s 153ms/step - loss: 0.8497 - accuracy: 0.6972 - val_loss: 0.8751 - val_accuracy: 0.6825
50
# 673/673 [==============================] - 98s 146ms/step - loss: 0.1819 - accuracy: 0.9370 - val_loss: 0.5458 - val_accuracy: 0.8349
# Epoch 30/50
# 673/673 [==============================] - 99s 148ms/step - loss: 0.1847 - accuracy: 0.9352 - val_loss: 0.5577 - val_accuracy: 0.8517
# Epoch 31/50
# 673/673 [==============================] - 99s 148ms/step - loss: 0.1727 - accuracy: 0.9393 - val_loss: 0.5462 - val_accuracy: 0.8520
# Epoch 32/50
# 673/673 [==============================] - 100s 148ms/step - loss: 0.1869 - accuracy: 0.9358 - val_loss: 0.5258 - val_accuracy: 0.8520
# Epoch 33/50
# 673/673 [==============================] - 100s 148ms/step - loss: 0.1557 - accuracy: 0.9448 - val_loss: 0.5118 - val_accuracy: 0.8595
# Epoch 34/50
# 673/673 [==============================] - 99s 147ms/step - loss: 0.1475 - accuracy: 0.9494 - val_loss: 0.5368 - val_accuracy: 0.8569
# Epoch 35/50
# 673/673 [==============================] - 99s 147ms/step - loss: 0.1570 - accuracy: 0.9433 - val_loss: 0.6387 - val_accuracy: 0.8387
# Epoch 36/50
# 673/673 [==============================] - 99s 147ms/step - loss: 0.1629 - accuracy: 0.9430 - val_loss: 0.5222 - val_accuracy: 0.8543
# Epoch 37/50
# 673/673 [==============================] - 99s 147ms/step - loss: 0.1416 - accuracy: 0.9511 - val_loss: 0.5027 - val_accuracy: 0.8651
# Epoch 38/50
# 673/673 [==============================] - 99s 147ms/step - loss: 0.1291 - accuracy: 0.9546 - val_loss: 0.5345 - val_accuracy: 0.8651
# Epoch 39/50
# 673/673 [==============================] - 99s 147ms/step - loss: 0.1485 - accuracy: 0.9489 - val_loss: 0.5798 - val_accuracy: 0.8569
# Epoch 40/50
# 673/673 [==============================] - 101s 149ms/step - loss: 0.1329 - accuracy: 0.9526 - val_loss: 0.5281 - val_accuracy: 0.8639
# Epoch 41/50
# 673/673 [==============================] - 100s 149ms/step - loss: 0.1254 - accuracy: 0.9578 - val_loss: 0.5749 - val_accuracy: 0.8472
# Epoch 42/50
# 673/673 [==============================] - 100s 149ms/step - loss: 0.1284 - accuracy: 0.9556 - val_loss: 0.5797 - val_accuracy: 0.8572
# Epoch 43/50
# 673/673 [==============================] - 98s 145ms/step - loss: 0.1152 - accuracy: 0.9595 - val_loss: 0.5561 - val_accuracy: 0.8684
# Epoch 44/50
# 673/673 [==============================] - 99s 147ms/step - loss: 0.1311 - accuracy: 0.9561 - val_loss: 0.5296 - val_accuracy: 0.8621
# Epoch 45/50
# 673/673 [==============================] - 98s 145ms/step - loss: 0.1098 - accuracy: 0.9632 - val_loss: 0.5842 - val_accuracy: 0.8535
# Epoch 46/50
# 673/673 [==============================] - 98s 146ms/step - loss: 0.1195 - accuracy: 0.9600 - val_loss: 0.6011 - val_accuracy: 0.8639
# Epoch 47/50
# 673/673 [==============================] - 98s 146ms/step - loss: 0.1072 - accuracy: 0.9640 - val_loss: 0.6243 - val_accuracy: 0.8554
# Epoch 48/50
# 673/673 [==============================] - 99s 147ms/step - loss: 0.1190 - accuracy: 0.9594 - val_loss: 0.6474 - val_accuracy: 0.8524
# Epoch 49/50
# 673/673 [==============================] - 98s 146ms/step - loss: 0.1070 - accuracy: 0.9637 - val_loss: 0.5910 - val_accuracy: 0.8602
# Epoch 50/50
# 673/673 [==============================] - 98s 146ms/step - loss: 0.0933 - accuracy: 0.9666 - val_loss: 0.6540 - val_accuracy: 0.8595
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, gru_cell_16_layer_call_fn, gru_cell_16_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: simple_rnn_GRU_model\assets
# INFO:tensorflow:Assets written to: simple_rnn_GRU_model\assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x000001C3CC13D4F0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001C3CCD33E50> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x000001C3E9998FD0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001C3D3308940> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %% [markdown]
# Final Evaluation  - Model 3 is best

# %%
model3 = load_model('mixed_rnn_model')
model3.evaluate(x={'audio_in': x_valid_audio, 'theme_in': x_valid_theme},y={'op': y_valid})
# Out:
# 85/85 [==============================] - 5s 41ms/step - loss: 0.7179 - accuracy: 0.8494
# [0.7179346084594727, 0.8494423627853394]

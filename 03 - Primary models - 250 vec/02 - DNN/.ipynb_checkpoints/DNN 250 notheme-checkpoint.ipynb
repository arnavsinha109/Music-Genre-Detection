# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %% [markdown]
# The main aim of this notebook is to train DNN models for 250 dimension dataset without the use of theme part.

# %%
musicFeatures = pd.read_pickle("./musicFeatures.pkl")

# %%
musicFeatures.shape
# Out:
# (26900, 22)

# %%
musicFeatures.head(3)
# Out:
#          id genre                                      mfccFeature_0  \
# 0  124425_0  Folk  [-367.4169, -240.58614, -193.78488, -180.29262...
# 1  124425_1  Folk  [-176.67264, -169.07156, -142.83098, -116.0994...
# 2  124425_2  Folk  [-112.90256, -84.587326, -92.53052, -99.84867,...
#
#                                        mfccFeature_1  \
# 0  [163.79123, 170.1294, 171.51189, 161.30435, 14...
# 1  [125.95861, 142.0693, 138.62712, 128.68915, 12...
# 2  [118.598724, 102.67175, 82.80994, 73.35031, 71...
#
#                                        mfccFeature_2  \
# 0  [6.0959854, -5.9718704, -3.6486344, -1.2554941...
# 1  [-42.819057, -54.282654, -64.97652, -73.68849,...
# 2  [-33.237568, -38.343197, -34.45424, -24.077305...
#
#                                        mfccFeature_3  \
# 0  [53.194122, 63.06723, 60.13885, 54.763412, 52....
# 1  [68.79902, 82.17572, 71.34984, 73.27362, 84.63...
# 2  [50.234768, 52.99376, 56.314552, 51.52988, 53....
#
# ...

# %%
"""
Verifying all shapres and types of data
"""
print(musicFeatures.shape)
print('MFCC Features \n')
print(type(musicFeatures['mfccFeature_0'].iloc[0]))
print(len(musicFeatures['mfccFeature_0'].iloc[0]))
print(type(musicFeatures['mfccFeature_0'].iloc[0][0]))

print('Theme Features \n')
print(type(musicFeatures['themeFeature_0'].iloc[0]))
print(musicFeatures['themeFeature_0'].iloc[0].size)
print(type(musicFeatures['themeFeature_0'].iloc[0][0]))
# Out:
# (26900, 22)
# MFCC Features
#
# <class 'numpy.ndarray'>
# 250
# <class 'numpy.float64'>
# Theme Features
#
# <class 'numpy.ndarray'>
# 250
# <class 'numpy.float64'>

# %% [markdown]
# We split the dataset into x and y, y having the predicting columns, we also drop the theme features as it is not needed

# %%
#Spliting x and y

y = musicFeatures['genre']
x = musicFeatures.loc[:, musicFeatures.columns != 'genre']
x = x.drop(['id','themeFeature_0','themeFeature_1','themeFeature_2','themeFeature_3','themeFeature_4'],axis =1)

print(x.shape)
print(y.shape)
# Out:
# (26900, 15)
# (26900,)

# %% [markdown]
# Since we have an np array as in each cell, we need to reshape the data into a 3d array for the network, we use the following function for the same.

# %%
def convertTo3DnpArray(df):
    new = []

    for index, row in df.iterrows():
        temp = []
        for i in row:
            temp.append(i)
        temp = np.stack(temp, axis=1)
        new.append(temp)
    new = np.stack(new, axis=0)
    
    return new

# %% [markdown]
# We split the dataset into train,test and valid which is of the ratio 80:10:10. Each model is trained on train and tested on test, once the best model is identified, we do a final validation on valid dataset.

# %%
#Train test valid split

x_train_temp, x_valid, y_train_temp, y_valid = train_test_split(x,y,test_size=0.1,random_state=12,stratify=y)
x_train, x_test, y_train, y_test = train_test_split(x_train_temp,y_train_temp,test_size=0.1/0.9,random_state=12,stratify=y_train_temp)

print('Final Sizes of all datasets')
print('x_train :',x_train.shape)
print('x_test :',x_test.shape)
print('x_valid :',x_valid.shape)
print('y_train :',y_train.shape)
print('y_test :',y_test.shape)
print('y_valid :',y_valid.shape)
print(' \n')

print('Value counts ')
print('y_train :')
print(y_train.value_counts())
print('y_test :')
print(y_test.value_counts())
print('y_valid :')
print(y_valid.value_counts())
# Out:
# Final Sizes of all datasets
# x_train : (21520, 15)
# x_test : (2690, 15)
# x_valid : (2690, 15)
# y_train : (21520,)
# y_test : (2690,)
# y_valid : (2690,)
#
#
# Value counts
# y_train :
# Rock            3820
# Hip-Hop         3304
# Experimental    3228
# Folk            3224
# Electronic      3192
# Pop             2428
# Instrumental    2324
# Name: genre, dtype: int64
# y_test :
# Rock            477
# Hip-Hop         413
# Experimental    404
# Folk            403
# Electronic      399
# Pop             303
# Instrumental    291
# Name: genre, dtype: int64
# y_valid :
# Rock            478
# Hip-Hop         413
# Folk            403
# Experimental    403
# Electronic      399
# Pop             304
# Instrumental    290
# Name: genre, dtype: int64

# %%
#splitting dataset into two parts

x_train_audio = convertTo3DnpArray(x_train.iloc[:,0:15])
x_test_audio = convertTo3DnpArray(x_test.iloc[:,0:15])
x_valid_audio = convertTo3DnpArray(x_valid.iloc[:,0:15])

print(x_train_audio.shape)
# Out:
# (21520, 250, 15)

# %%
x_train.iloc[:,0:15]
# Out:
#                                            mfccFeature_0  \
# 35394  [-259.05927, -239.89516, -210.36134, -191.0854...
# 34049  [-188.014, -206.20021, -225.0521, -220.18987, ...
# 34247  [-82.13368, -56.982624, -58.14949, -60.955105,...
# 35132  [-74.62353, -47.188427, -43.740658, -31.355085...
# 22687  [-10.387641, -2.7015615, -25.830664, -42.18832...
# ...                                                  ...
# 34612  [-22.075876, 17.469933, 41.13768, 47.155334, 2...
# 16319  [-92.643814, -106.90123, -146.92157, -146.6631...
# 32007  [-46.454754, -11.053625, -34.104454, -86.73249...
# 25302  [-67.69743, -45.990658, -48.59186, -45.082943,...
# 14597  [-431.63876, -425.94974, -425.71237, -416.3972...
#
#                                            mfccFeature_1  \
# 35394  [95.85247, 89.139465, 100.31354, 114.44683, 12...
# 34049  [128.69154, 141.3887, 154.6398, 159.06891, 149...
# 34247  [74.79721, 72.48038, 69.69021, 71.89056, 76.14...
# ...

# %% [markdown]
# We convert the y values into one hot encoded values.

# %%
ohe = OneHotEncoder()

y_valid = ohe.fit_transform(y_valid.values.reshape(-1, 1)).toarray()
y_train = ohe.fit_transform(y_train.values.reshape(-1, 1)).toarray()
y_test  = ohe.fit_transform(y_test .values.reshape(-1, 1)).toarray()

print('Verifying size')
print('y_train :',y_train.shape)
print('y_test :',y_test.shape)
print('y_valid :',y_valid.shape)
# Out:
# Verifying size
# y_train : (21520, 7)
# y_test : (2690, 7)
# y_valid : (2690, 7)

# %%
from keras.models import Sequential,load_model
from keras.layers import Dense,GRU,Flatten,concatenate,Dropout,LSTM,Conv2D,MaxPooling2D,BatchNormalization,Dropout,Flatten
import tensorflow as tf
from keras import Model
from keras.layers import Input, Dense, Bidirectional
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# The following function is used to plot the graphs for train and loss accuracy.

# %%
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Test acc')
    plt.title('Training and test accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Test loss')
    plt.title('Training and test loss')
    plt.legend()

# %% [markdown]
# We build a small and simple DNN model

# %%
audio_in = Input(shape=(x_train_audio.shape[1], x_train_audio.shape[2]), name='audio_in')

dense1 = Dense(64, activation='relu')(audio_in)
dense2 = Dense(32, activation='relu')(dense1)
dense3 = Dense(16, activation='relu')(dense2)
flat = Flatten()(dense3)
op = Dense(7, activation='softmax',name='op')(flat)


model = Model(inputs=[audio_in], outputs=[op])

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  audio_in (InputLayer)       [(None, 250, 15)]         0
#
#  dense (Dense)               (None, 250, 64)           1024
#
#  dense_1 (Dense)             (None, 250, 32)           2080
#
#  dense_2 (Dense)             (None, 250, 16)           528
#
#  flatten (Flatten)           (None, 4000)              0
#
#  op (Dense)                  (None, 7)                 28007
#
# ...
# Total params: 31,639
# Trainable params: 31,639
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam',
                     loss='categorical_crossentropy',
                     metrics = ['accuracy']
                     )


h=model.fit({'audio_in': x_train_audio},{'op': y_train},
              epochs=200, batch_size=32,
            validation_data=({'audio_in': x_test_audio},{'op': y_test}))


model.save('simple_dnn_model')


plot_history(h)
# Out:
# Epoch 1/200
# 673/673 [==============================] - 3s 4ms/step - loss: 2.1362 - accuracy: 0.2783 - val_loss: 1.7792 - val_accuracy: 0.3320
# Epoch 2/200
# 673/673 [==============================] - 3s 4ms/step - loss: 1.7042 - accuracy: 0.3447 - val_loss: 1.7056 - val_accuracy: 0.3409
# Epoch 3/200
# 673/673 [==============================] - 3s 4ms/step - loss: 1.6659 - accuracy: 0.3543 - val_loss: 1.7251 - val_accuracy: 0.3193
# Epoch 4/200
# 673/673 [==============================] - 3s 4ms/step - loss: 1.6120 - accuracy: 0.3742 - val_loss: 1.7407 - val_accuracy: 0.3401
# Epoch 5/200
# 673/673 [==============================] - 3s 4ms/step - loss: 1.5989 - accuracy: 0.3762 - val_loss: 1.6902 - val_accuracy: 0.3472
# Epoch 6/200
# 673/673 [==============================] - 3s 4ms/step - loss: 1.5473 - accuracy: 0.4008 - val_loss: 1.7413 - val_accuracy: 0.3290
# Epoch 7/200
# ...

# %% [markdown]
# We increase the number of layers and make it bigger

# %%
audio_in = Input(shape=(x_train_audio.shape[1], x_train_audio.shape[2]), name='audio_in')

dense1 = Dense(512, activation='relu')(audio_in)
dense2 = Dense(256, activation='relu')(dense1)
dense3 = Dense(128, activation='relu')(dense2)
dense4 = Dense(128, activation='relu')(dense3)
dense5 = Dense(128, activation='relu')(dense4)
dense6 = Dense(64, activation='relu')(dense5)
dense7 = Dense(32, activation='relu')(dense6)
dense8 = Dense(16, activation='relu')(dense7)
flat = Flatten()(dense8)
op = Dense(7, activation='softmax',name='op')(flat)


model2 = Model(inputs=[audio_in], outputs=[op])

model2.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  audio_in (InputLayer)       [(None, 250, 15)]         0
#
#  dense_7 (Dense)             (None, 250, 512)          8192
#
#  dense_8 (Dense)             (None, 250, 256)          131328
#
#  dense_9 (Dense)             (None, 250, 128)          32896
#
#  dense_10 (Dense)            (None, 250, 128)          16512
#
#  dense_11 (Dense)            (None, 250, 128)          16512
#
#  dense_12 (Dense)            (None, 250, 64)           8256
#
#  dense_13 (Dense)            (None, 250, 32)           2080
#
#  dense_14 (Dense)            (None, 250, 16)           528
#
#  flatten_1 (Flatten)         (None, 4000)              0
#
#  op (Dense)                  (None, 7)                 28007
#
# ...
# Total params: 244,311
# Trainable params: 244,311
# Non-trainable params: 0
# ...

# %%
#Long DNN model

model2.compile(optimizer = 'adam',
                     loss='categorical_crossentropy',
                     metrics = ['accuracy']
                     )


h2=model2.fit({'audio_in': x_train_audio},{'op': y_train},
              epochs=200, batch_size=16,
            validation_data=({'audio_in': x_test_audio},{'op': y_test}))


model2.save('long_dnn_model')


plot_history(h2)
# Out:
# Epoch 1/200
# 1345/1345 [==============================] - 30s 22ms/step - loss: 1.7174 - accuracy: 0.3278 - val_loss: 1.6540 - val_accuracy: 0.3558
# Epoch 2/200
# 1345/1345 [==============================] - 31s 23ms/step - loss: 1.6168 - accuracy: 0.3613 - val_loss: 1.6114 - val_accuracy: 0.3632
# Epoch 3/200
# 1345/1345 [==============================] - 31s 23ms/step - loss: 1.5598 - accuracy: 0.4114 - val_loss: 1.5487 - val_accuracy: 0.4182
# Epoch 4/200
# 1345/1345 [==============================] - 32s 24ms/step - loss: 1.5179 - accuracy: 0.4341 - val_loss: 1.5090 - val_accuracy: 0.4457
# Epoch 5/200
# 1345/1345 [==============================] - 32s 24ms/step - loss: 1.4621 - accuracy: 0.4621 - val_loss: 1.4864 - val_accuracy: 0.4558
# Epoch 6/200
# 1345/1345 [==============================] - 33s 24ms/step - loss: 1.4256 - accuracy: 0.4788 - val_loss: 1.5154 - val_accuracy: 0.4513
# Epoch 7/200
# ...

# %% [markdown]
# Similar Architecture as before but we flatten it early

# %%
audio_in = Input(shape=(x_train_audio.shape[1], x_train_audio.shape[2]), name='audio_in')
flat = Flatten()(audio_in)
dense1 = Dense(512, activation='relu')(flat)
dense2 = Dense(256, activation='relu')(dense1)
dense3 = Dense(128, activation='relu')(dense2)
dense4 = Dense(128, activation='relu')(dense3)
dense5 = Dense(128, activation='relu')(dense4)
dense6 = Dense(64, activation='relu')(dense5)
dense7 = Dense(32, activation='relu')(dense6)
dense8 = Dense(16, activation='relu')(dense7)
op = Dense(7, activation='softmax',name='op')(dense8)


model3 = Model(inputs=[audio_in], outputs=[op])

model3.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  audio_in (InputLayer)       [(None, 250, 15)]         0
#
#  flatten_2 (Flatten)         (None, 3750)              0
#
#  dense_15 (Dense)            (None, 512)               1920512
#
#  dense_16 (Dense)            (None, 256)               131328
#
#  dense_17 (Dense)            (None, 128)               32896
#
#  dense_18 (Dense)            (None, 128)               16512
#
#  dense_19 (Dense)            (None, 128)               16512
#
#  dense_20 (Dense)            (None, 64)                8256
#
#  dense_21 (Dense)            (None, 32)                2080
#
#  dense_22 (Dense)            (None, 16)                528
#
#  op (Dense)                  (None, 7)                 119
#
# ...
# Total params: 2,128,743
# Trainable params: 2,128,743
# Non-trainable params: 0
# ...

# %%
#Early flatten Long DNN model

model3.compile(optimizer = 'adam',
                     loss='categorical_crossentropy',
                     metrics = ['accuracy']
                     )


h3=model3.fit({'audio_in': x_train_audio},{'op': y_train},
              epochs=200, batch_size=16,
            validation_data=({'audio_in': x_test_audio},{'op': y_test}))


model3.save('long_dnn_model')


plot_history(h3)
# Out:
# Epoch 1/200
# 1345/1345 [==============================] - 9s 6ms/step - loss: 1.8550 - accuracy: 0.3419 - val_loss: 1.6521 - val_accuracy: 0.3602
# Epoch 2/200
# 1345/1345 [==============================] - 10s 7ms/step - loss: 1.6248 - accuracy: 0.3890 - val_loss: 1.6413 - val_accuracy: 0.3732
# Epoch 3/200
# 1345/1345 [==============================] - 10s 7ms/step - loss: 1.5914 - accuracy: 0.4057 - val_loss: 1.6104 - val_accuracy: 0.4059
# Epoch 4/200
# 1345/1345 [==============================] - 10s 7ms/step - loss: 1.5736 - accuracy: 0.4153 - val_loss: 1.6114 - val_accuracy: 0.3985
# Epoch 5/200
# 1345/1345 [==============================] - 9s 7ms/step - loss: 1.5511 - accuracy: 0.4261 - val_loss: 1.5939 - val_accuracy: 0.4138
# Epoch 6/200
# 1345/1345 [==============================] - 7s 6ms/step - loss: 1.5216 - accuracy: 0.4323 - val_loss: 1.5569 - val_accuracy: 0.4201
# Epoch 7/200
# ...

# %% [markdown]
# Final Evaluation - Best model is model3

# %%
model3.evaluate({'audio_in': x_valid_audio},{'op': y_valid})
# Out:
# 85/85 [==============================] - 0s 2ms/step - loss: 3.8777 - accuracy: 0.4770
# [3.8776955604553223, 0.4769516587257385]
